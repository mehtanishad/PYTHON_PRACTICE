# %%
import turtle
pen = turtle.Turtle()
def curve():
  for i in range(200):
    pen.right(1)
    pen.forward(1)

def heart():
  pen.fillcolor('red')
  pen.begin_fill()
  pen.left(140)
  pen.forward(113)
  curve()
  pen.left(120)
  curve()
  pen.forward(112)
  pen.end_fill()
def txt():
  pen.up()
  pen.setpos(-68,95)
  pen.down()
  pen.color('yello')
  pen.write("tops technologys",font=("verdana",15,"bold"))

heart()
txt()
pen.ht()
turtle
turtle.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# TurtleGraphicsError                       Traceback (most recent call last)
# c:\Users\tops\Downloads\heart.py.ipynb Cell 1 in <cell line: 26>()
#      <a href='vscode-notebook-cell:/c%3A/Users/tops/Downloads/heart.py.ipynb#W0sZmlsZQ%3D%3D?line=22'>23</a>   pen.write("tops technologys",font=("verdana",15,"bold"))
#      <a href='vscode-notebook-cell:/c%3A/Users/tops/Downloads/heart.py.ipynb#W0sZmlsZQ%3D%3D?line=24'>25</a> heart()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/tops/Downloads/heart.py.ipynb#W0sZmlsZQ%3D%3D?line=25'>26</a> txt()
#      <a href='vscode-notebook-cell:/c%3A/Users/tops/Downloads/heart.py.ipynb#W0sZmlsZQ%3D%3D?line=26'>27</a> pen.ht()
#      <a href='vscode-notebook-cell:/c%3A/Users/tops/Downloads/heart.py.ipynb#W0sZmlsZQ%3D%3D?line=27'>28</a> turtle
#
# c:\Users\tops\Downloads\heart.py.ipynb Cell 1 in txt()
# ...
