# %%
d={'name':'nishad','age':'22'}

# %%
type(d)
# Out:
# dict

# %%
len(d)
# Out:
# 2

# %%
d.setdefault('name')
# Out:
# 'nishad'

# %%
d.setdefault('age')
# Out:
# '22'

# %%
d.update({'name':'nishad','mobile':'7041719331'})

# %%
d
# Out:
# {'name': 'nishad', 'age': '22', 'mobile': '7041719331'}

# %%
d.get('name',)
# Out:
# 'nishad'

# %%
d.get('surname')

# %%
d
# Out:
# {'name': 'nishad', 'age': '22', 'mobile': '7041719331'}

# %%
d['name'] = 'NISHAD'

# %%
d
# Out:
# {'name': 'NISHAD', 'age': '22', 'mobile': '7041719331'}

# %%
d['age'] = '25'

# %%
d
# Out:
# {'name': 'NISHAD', 'age': '25', 'mobile': '7041719331'}

# %%
d.keys()
# Out:
# dict_keys(['name', 'age', 'mobile'])

# %%
d.values()
# Out:
# dict_values(['NISHAD', '25', '7041719331'])

# %%
d.items()
# Out:
# dict_items([('name', 'NISHAD'), ('age', '25'), ('mobile', '7041719331')])

# %%
d.popitem()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-83c64cff336b> in <module>
# ----> 1 d.popitem()
#
# KeyError: 'popitem(): dictionary is empty'

# %%
d
# Out:
# {}

# %%
d
# Out:
# {}

# %%
d  = {'name':'nishad','age':'22'}

# %%
d
# Out:
# {'name': 'nishad', 'age': '22'}

# %%
d['age']
# Out:
# '22'

# %%
del d['name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-03038286f9ca> in <module>
# ----> 1 del d['name']
#
# KeyError: 'name'

# %%
d
# Out:
# {}

# %%
a=5

# %%
a
# Out:
# 5

# %%
del a

# %%
d2 = dict.fromkeys(['name','age','mobile'],"@@@@@@@@@@@@")

# %%
d2
# Out:
# {'name': '@@@@@@@@@@@@', 'age': '@@@@@@@@@@@@', 'mobile': '@@@@@@@@@@@@'}

# %%
d2.clear()

# %%
d2
# Out:
# {}

# %%
a=5

# %%
a
# Out:
# 5

# %%
b=a

# %%
b
# Out:
# 5

# %%
a=6

# %%
a
# Out:
# 6

# %%
b
# Out:
# 5

# %%
d={ 'name':'nishad','age':'22'}

# %%
d
# Out:
# {'name': 'nishad', 'age': '22'}

# %%
d3=d

# %%
d3
# Out:
# {'name': 'nishad', 'age': '22'}

# %%
d['mobile'] =7041719331

# %%
d
# Out:
# {'name': 'nishad', 'age': '22', 'mobile': 7041719331}

# %%
d4=d.copy()

# %%
d4
# Out:
# {'name': 'nishad', 'age': '22', 'mobile': 7041719331}

# %%
d.pop('mobile')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-115-101882402a42> in <module>
# ----> 1 d.pop('mobile')
#
# KeyError: 'mobile'

# %%
d
# Out:
# {'name': 'nishad', 'age': '22'}

# %%
d3
# Out:
# {'name': 'nishad', 'age': '22'}

# %%
d4
# Out:
# {'name': 'nishad', 'age': '22', 'mobile': 7041719331}

# %%
id(d)
# Out:
# 139793217635424

# %%
id(d2)
# Out:
# 139793217694928

# %%
id(d3)
# Out:
# 139793217635424

# %%
id(d4)
# Out:
# 139793217168800

# %%
l=[1,2]
l2=[3,4,5,]
l3=[6,7,8,]

# %%
l,l2,l3
# Out:
# ([1, 2], [3, 4, 5], [6, 7, 8])

# %%
list=[99,77,88,55,]
list2=[2,5,6,]

# %%
list
list2
# Out:
# [2, 5, 6]

# %%
list.append(22)

# %%
list
# Out:
# [99, 77, 88, 55, 22, 22]

# %%
list.extend(list2)

# %%
list
# Out:
# [99, 77, 88, 55, 2, 5, 6, 2, 5, 6]

# %%
list
# Out:
# [99, 77, 88, 55, 2, 5, 6, 2, 5, 6]

# %%
list.pop(3)
# Out:
# 2

# %%
list.insert(2,66)

# %%
list
# Out:
# [99, 77, 66, 66, 88, 5, 2, 5, 6]

# %%
list.pop()
# Out:
# 5

# %%
list
# Out:
# [99, 77, 66, 66, 88, 5, 2]

# %%
list.pop()
# Out:
# 5

# %%
list
# Out:
# [99, 77, 66, 66, 88]

# %%
list
# Out:
# [99, 77, 66, 66, 88]

# %%
list.remove(66)

# %%
list
# Out:
# [99, 77, 88]

# %%
list.reverse()

# %%
list
# Out:
# [99, 77, 88]

# %%
list.reverse()

# %%
list
# Out:
# [99, 77, 88]

# %%
list.sort()

# %%
list
# Out:
# [77, 88, 99]

# %%
list.reverse()

# %%
list
# Out:
# [77, 88, 99]

# %%
list.sort(reverse=False)

# %%
list
# Out:
# [77, 88, 99]

# %%
l=['n','i','s','h','a','d']
print(l[2])
print(l[5])
# Out:
# s
# d

# %%
l=['n','i','s','h','a','d']
print(l[2:3])
print(l[2:])
print(l[:])
# Out:
# ['s']
# ['s', 'h', 'a', 'd']
# ['n', 'i', 's', 'h', 'a', 'd']

# %%
l=[1,2,3]
l.append(7)
print(l)
l.extend([9,10,11,13])
print(l)
# Out:
# [1, 2, 3, 7]
# [1, 2, 3, 7, 9, 10, 11, 13]

# %%
l
# Out:
# ['n', 'i', 's', 'h', 'a', 'd']
