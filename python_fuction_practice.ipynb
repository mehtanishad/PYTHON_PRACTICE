# %%
def age(birthday):
  today= date.today()
  age.today.year-birthdate.year-((todat.month,today.day)<(birthdate.month,birthdate.dsay))
  return age

# %%
def add(a,b, *number):
  s = (a + b)
  for i in number:
    s +=i

  return s

# %%
add(1,2,3,4,5,6,6,7,8,9,10,11,12)
# Out:
# 84

# %% [markdown]
# Write a Python function to calculate the factorial of a number (a
# nonnegative integer).

# %%
def factorial(n):
  if n == 0:
    return 1
  else:
    return n * factorial(n-1)
n= int(input("enter a numbe : "))
print(factorial(n))
# Out:
# enter a numbe : 5
# 120

# %%
Write a Python function to check whether a number is in a given range.

# %%
def range(n):
  if n in range(3,9):
      print( " %s is in the range"%str(n))
  else:
      print("The number is outside the given range.")
  range(5)

# %%
Write a Python function that checks whether a passed string is
palindrome or not.

# %%
def isPalindrome(s):
    return s == s[::-1]
 
s = "nayan"
ans = isPalindrome(s)
 
if ans:
    print("palindrome")
else:
    print("Not palindrome")
# Out:
# palindrome

# %% [markdown]
# How Many Basic Types Of Functions Are Available In Python?
#
# There are two basic types of functions
# 1.Built-in function - print(), help(), len(), type(), id() etc.
# 2.User defined function - We can define ourselves to do certain specific task are referred as user-defined functions.

# %%
How can you pick a random item from a list or tuple?

# %%
import random
list = [1, 2, 3, 4, 5, 6]
get_index = random.randrange(len(list))
 
print(list[get_index])
# Out:
# 6

# %% [markdown]
# How can you pick a random item from a range.

# %%
import random
num1 = random.randrange(0, 9)
print(num1)
# Out:
# 3

# %%
How can you get a random number in python?

# %%
import random
n = random.random()
print(n)
# Out:
# 0.19325383856596356

# %%
def my_function(*kids):
  print("The youngest child is " + kids[3])

my_function("Emil", "Tobias", "Linus","eti")
# Out:
# The youngest child is eti

# %%
import random
list=[10,55,40,80,20,25];
random.shuffle(list)
print("reshuffled list:", list)
random.shuffle(list)
print("reshuffled list:", list)
# Out:
# reshuffled list: [20, 40, 55, 10, 80, 25]
# reshuffled list: [40, 20, 80, 10, 25, 55]

# %%
Write a Python function to reverses a string if its length is a multiple of 4.

# %% [markdown]
#  Reverse a string if it's length is a multiple of 4.

# %%
def reverse_string(str1):
    if len(str1) % 4 == 0:
       return '' .join(reversed(str1))
    return str1

print(reverse_string('abcd')) 
print(reverse_string('pythonapi'))
# Out:
# dcba
# pythonapi
