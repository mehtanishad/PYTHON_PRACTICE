# %%
# try/except
print(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\python\python_practice\phthon_exception_handling.ipynb Cell 1 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> # try/except
# ----> <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> print(name)
#
# NameError: name 'name' is not defined

# %%
print('before')

print(address)

print('after')
# Out:
# before
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\python\python_practice\phthon_exception_handling.ipynb Cell 2 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> print('before')
# ----> <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> print(address)
#       <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> print('after')
#
# NameError: name 'address' is not defined

# %%
try:
    print(name)
except:
    print('something wrong')
finally:
    print('something')
# Out:
# something wrong
# something

# %%
try:
  age = input('enter your age: ')

  if age >= 18:
    print('eligible')
  else:
    print('not eligible')
except:
  print('something went wrong')
# Out:
# something went wrong

# %%
try:
    print(addresss)
except exception as err:
    print(err)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\python\python_practice\phthon_exception_handling.ipynb Cell 5 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> try:
# ----> <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a>     print(addresss)
#       <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> except exception as err:
#
# NameError: name 'addresss' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# d:\python\python_practice\phthon_exception_handling.ipynb Cell 5 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> try:
#       <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a>     print(addresss)
# ----> <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> except exception as err:
#       <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a>     print(err)
#
# NameError: name 'exception' is not defined

# %%
try:
    name="nishad"

    print(name, name.index('x'))
except NameError as err:
    print(err)
except ValueError as err:
    print(err)
except TypeError as err:
    print(err)
# Out:
# substring not found

# %%
try:
    name="nishad"
    print(name,name[10])
except (NameError,ValueError,TypeError) as err:
    print(err)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\python\python_practice\phthon_exception_handling.ipynb Cell 7 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> try:
#       <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a>     name="nishad"
# ----> <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a>     print(name,name[10])
#       <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> except (NameError,ValueError,TypeError) as err:
#       <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a>     print(err)
#
# IndexError: string index out of range

# %%
try:
    name="nishad"
    print(name,name[10])
except (NameError,ValueError,TypeError) as err:
    print(err)
finally:
    print('done')
# Out:
# done
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\python\python_practice\phthon_exception_handling.ipynb Cell 8 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> try:
#       <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a>     name="nishad"
# ----> <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a>     print(name,name[10])
#       <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> except (NameError,ValueError,TypeError) as err:
#       <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a>     print(err)
#
# IndexError: string index out of range

# %%
raise Exception('manually raised')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# d:\python\python_practice\phthon_exception_handling.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> raise Exception('manually raised')
#
# Exception: manually raised

# %%
raise ValueError('data not found')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\python\python_practice\phthon_exception_handling.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> raise ValueError('data not found')
#
# ValueError: data not found

# %%
age=input('enter your age: ')
if age.isnumeric():
    if int(age) >=18:
        print('eligible')
    else:
            raise TypeError ('not eligible')
else:
        raise ValueError('enter numeric value')
# Out:
# eligible

# %%
try:
    age=input('enter your age: ')
    if age.isnumeric():
        if int(age) >=18:
            print('eligible')
        else:
            raise TypeError('not eligible')
    else:
        raise ValueError('enter numeric value only')
except exception as err:
    print(err)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\python\python_practice\phthon_exception_handling.ipynb Cell 12 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a>     else:
# ----> <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#X21sZmlsZQ%3D%3D?line=6'>7</a>         raise TypeError('not eligible')
#       <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#X21sZmlsZQ%3D%3D?line=7'>8</a> else:
#
# TypeError: not eligible
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# d:\python\python_practice\phthon_exception_handling.ipynb Cell 12 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#X21sZmlsZQ%3D%3D?line=7'>8</a>     else:
#       <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#X21sZmlsZQ%3D%3D?line=8'>9</a>         raise ValueError('enter numeric value only')
# ---> <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#X21sZmlsZQ%3D%3D?line=9'>10</a> except exception as err:
#      <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#X21sZmlsZQ%3D%3D?line=10'>11</a>     print(err)
#
# NameError: name 'exception' is not defined

# %%
try:
  age = input('enter your age: ')
  if age.isnumeric():
    if int(age) >= 18:
      print('eligible')
    else:
      raise TypeError('not eligible')
  else:
    raise ValueError('Please enter numeric value only.')
except Exception as err:
  print(err)
# Out:
# not eligible

# %%
assert False, "conditionaly triggered"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# d:\python\python_practice\phthon_exception_handling.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/python/python_practice/phthon_exception_handling.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> assert False, "conditionaly triggered"
#
# AssertionError: conditionaly triggered

# %%
age = input('enter your age: ')
assert age.isnumeric(), 'enter the numeric value'
assert int(age) >=18, 'not eligible'
print(eligible)

# %%
try:
   age = input('enter your age: ')

   assert age.isnumeric(), 'enter the numeric value'

   assert int(age) >=18, 'not eligible'

   print('eligible')
except exception as err:
    print(err)
# Out:
# eligible
